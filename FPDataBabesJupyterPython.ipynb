# %% [markdown]
# # Import Packages

# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
from pylab import *
import seaborn as sns
# %matplotlib inline
import statsmodels.api as sm
import statsmodels.stats.api as sms
from scipy.stats import boxcox

# %%
RegularGas = pd.read_excel("C:/Users/dawne/OneDrive/Documents/Final Project/RegularGasPrice.xlsx")

# %%
RegularGas.head()
# Out:
#         Date  \
# 0 1990-08-20
# 1 1990-08-27
# 2 1990-09-03
# 3 1990-09-10
# 4 1990-09-17
#
#    Weekly U.S. Regular Conventional Retail Gasoline Prices  (Dollars per Gallon)  \
# 0                                              1.191
# 1                                              1.245
# 2                                              1.242
# 3                                              1.252
# 4                                              1.266
#
#    Weekly East Coast Regular Conventional Retail Gasoline Prices  (Dollars per Gallon)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Weekly New England (PADD 1A) Regular Conventional Retail Gasoline Prices  (Dollars per Gallon)  \
# 0                                                NaN
# ...

# %%
RegularGas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1661 entries, 0 to 1660
# Data columns (total 21 columns):
#  #   Column                                                                                               Non-Null Count  Dtype
# ---  ------                                                                                               --------------  -----
#  0   Date                                                                                                 1661 non-null   datetime64[ns]
#  1   Weekly U.S. Regular Conventional Retail Gasoline Prices  (Dollars per Gallon)                        1655 non-null   float64
#  2   Weekly East Coast Regular Conventional Retail Gasoline Prices  (Dollars per Gallon)                  1571 non-null   float64
#  3   Weekly New England (PADD 1A) Regular Conventional Retail Gasoline Prices  (Dollars per Gallon)       1524 non-null   float64
# ...

# %% [markdown]
# # Eliminate unnecessary data

# %%
RegularGas.dropna(inplace=True)

# %%
RegularGas.head()
# Out:
#           Date  \
# 666 2003-05-26
# 667 2003-06-02
# 668 2003-06-09
# 669 2003-06-16
# 670 2003-06-23
#
#      Weekly U.S. Regular Conventional Retail Gasoline Prices  (Dollars per Gallon)  \
# 666                                              1.439
# 667                                              1.428
# 668                                              1.456
# 669                                              1.480
# 670                                              1.451
#
#      Weekly East Coast Regular Conventional Retail Gasoline Prices  (Dollars per Gallon)  \
# 666                                              1.392
# 667                                              1.393
# 668                                              1.408
# 669                                              1.443
# 670                                              1.432
#
#      Weekly New England (PADD 1A) Regular Conventional Retail Gasoline Prices  (Dollars per Gallon)  \
# ...

# %%
NortheastUrbanPerBarrel = pd.read_excel("C:/Users/dawne/OneDrive/Documents/Final Project/NortheastPerBarrel.xlsx")

# %%
PricePerGallonUrban.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0       Year        Jan        Feb        Mar        Apr        May
# 1       2012    242.879     243.85    245.125     245.85    245.709
# 2       2013    247.277    248.665    248.719    248.464    248.584
# 3       2014    251.045    251.233    252.413    252.506    253.598
# 4       2015    250.016    250.619    251.451     251.76     252.77
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0        Jun        Jul        Aug        Sep         Oct         Nov
# 1    245.201    244.984    246.252    247.409     247.564     247.097
# 2    248.851    249.411    249.858    250.231      249.32     249.503
# 3    253.555    253.833    253.185    253.154      252.73     251.781
# 4    253.626    253.405    252.903    252.922     252.504     252.573
#
#   Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15
# 0         Dec      Annual       HALF1       HALF2
# ...

# %%
PricePerGallonUrban.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   12 non-null     object
#  1   Unnamed: 1   12 non-null     object
#  2   Unnamed: 2   12 non-null     object
#  3   Unnamed: 3   12 non-null     object
#  4   Unnamed: 4   12 non-null     object
#  5   Unnamed: 5   11 non-null     object
#  6   Unnamed: 6   11 non-null     object
#  7   Unnamed: 7   11 non-null     object
#  8   Unnamed: 8   11 non-null     object
#  9   Unnamed: 9   11 non-null     object
#  10  Unnamed: 10  11 non-null     object
#  11  Unnamed: 11  11 non-null     object
#  12  Unnamed: 12  11 non-null     object
#  13  Unnamed: 13  11 non-null     object
#  14  Unnamed: 14  11 non-null     object
#  15  Unnamed: 15  11 non-null     object
# dtypes: object(16)
# memory usage: 1.6+ KB

# %%
MidwestPerBarrel = pd.read_excel("C:/Users/dawne/OneDrive/Documents/MidwestPerBarrel.xlsx")

# %%
MidwestPerBarrel.head()
# Out:
#    Year      Jan      Feb      Mar      Apr      May      Jun      Jul  \
# 0  2012  216.368  216.855  218.975  219.405  219.145  219.017  218.956
# 1  2013  219.282  221.599  222.121  221.931  223.049  223.775  222.902
# 2  2014  222.247  223.493  225.485  226.214  226.565  227.588  226.997
# 3  2015  221.545  222.301  223.550  223.797  224.732  225.946  225.853
# 4  2016  223.301  223.196  224.621  225.609  226.476  227.835  226.786
#
#        Aug      Sep      Oct      Nov      Dec   Annual    HALF1    HALF2
# 0  220.462  221.125  220.375  219.483  219.033  219.100  218.294  219.906
# 1  223.046  223.252  222.171  221.718  221.194  222.170  221.960  222.381
# 2  226.587  226.913  225.793  224.396  222.821  225.425  225.265  225.585
# 3  225.830  225.184  225.050  224.009  222.722  224.210  223.645  224.775
# 4  227.097  227.636  227.358  226.673  226.794  226.115  225.173  227.057

# %%
MidwestPerBarrel.dropna(inplace=True)

# %%
MidwestPerBarrel.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 2       Year        Jan        Feb        Mar        Apr        May
# 3       2012    216.368    216.855    218.975    219.405    219.145
# 4       2013    219.282    221.599    222.121    221.931    223.049
# 5       2014    222.247    223.493    225.485    226.214    226.565
# 6       2015    221.545    222.301     223.55    223.797    224.732
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 2        Jun        Jul        Aug        Sep         Oct         Nov
# 3    219.017    218.956    220.462    221.125     220.375     219.483
# 4    223.775    222.902    223.046    223.252     222.171     221.718
# 5    227.588    226.997    226.587    226.913     225.793     224.396
# 6    225.946    225.853     225.83    225.184      225.05     224.009
#
#   Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15
# 2         Dec      Annual       HALF1       HALF2
# ...

# %%
MidwestPerBarrel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11 entries, 2 to 12
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   11 non-null     object
#  1   Unnamed: 1   11 non-null     object
#  2   Unnamed: 2   11 non-null     object
#  3   Unnamed: 3   11 non-null     object
#  4   Unnamed: 4   11 non-null     object
#  5   Unnamed: 5   11 non-null     object
#  6   Unnamed: 6   11 non-null     object
#  7   Unnamed: 7   11 non-null     object
#  8   Unnamed: 8   11 non-null     object
#  9   Unnamed: 9   11 non-null     object
#  10  Unnamed: 10  11 non-null     object
#  11  Unnamed: 11  11 non-null     object
#  12  Unnamed: 12  11 non-null     object
#  13  Unnamed: 13  11 non-null     object
#  14  Unnamed: 14  11 non-null     object
#  15  Unnamed: 15  11 non-null     object
# dtypes: object(16)
# memory usage: 1.5+ KB

# %%
AllGradesConvPerDollar = pd.read_excel("C:/Users/dawne/OneDrive/Documents/AllGradesConventionalPerDollar.xlsx")

# %%
AllGradesConvPerDollar.head()
# Out:
#         Date  WeeklyUS All Grades Conventional Retail Gasoline Prices    \
# 0 1994-11-28                                              1.175
# 1 1994-12-05                                              1.143
# 2 1994-12-12                                              1.118
# 3 1994-12-19                                              1.099
# 4 1994-12-26                                              1.088
#
#    Weekly East Coast All Grades Conventional Retail Gasoline Prices    \
# 0                                              1.208
# 1                                              1.183
# 2                                              1.160
# 3                                              1.141
# 4                                              1.134
#
#    Weekly New England (PADD 1A) All Grades Conventional Retail Gasoline Prices   \
# 0                                              1.232
# 1                                              1.202
# ...

# %%
AllGradesConvPerDollar.head()
# Out:
#         Date  WeeklyUS All Grades Conventional Retail Gasoline Prices    \
# 0 1994-11-28                                              1.175
# 1 1994-12-05                                              1.143
# 2 1994-12-12                                              1.118
# 3 1994-12-19                                              1.099
# 4 1994-12-26                                              1.088
#
#    Weekly East Coast All Grades Conventional Retail Gasoline Prices    \
# 0                                              1.208
# 1                                              1.183
# 2                                              1.160
# 3                                              1.141
# 4                                              1.134
#
#    Weekly New England (PADD 1A) All Grades Conventional Retail Gasoline Prices   \
# 0                                              1.232
# 1                                              1.202
# ...
